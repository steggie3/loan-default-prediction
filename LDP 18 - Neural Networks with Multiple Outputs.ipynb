# %% [markdown]
# # Loan Default Prediction - Part 17 - Neural Networks with Multiple Outputs
#
# This is an exploratory project for me to apply what I have learned in the Data Science and Machine Learning courses that I took this year. The data is from a Kaggle competition [Loan Default Prediction](https://www.kaggle.com/c/loan-default-prediction).
#
# This is Part 17 of the project: Neural Networks with Multiple Outputs.
#
# I have been working on the binary classification version of the loan default prediction problem. However, the original dataset also contains the percentage of loan not paid for, which is a regression problem. In this part, I will add a regression output in the neural network to predict the percentage.
#
# I will first load the normalized data.

# %%
# Import libraries

import numpy as np
import pandas as pd
import time
import project_utils as utils
import project_keras_utils as keras_utils
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# We need two sets of labels now, one for classification and one for regression

def load_csv(file, describe=False):
    df = pd.read_csv(file, na_values='NA')
    df = df.drop(['id', 'Unnamed: 0'], axis=1) # Dropping the ID column
    
    # Display basic information
    df.info()
    if describe:
        print(df.describe(include='all'))

    X = df.drop(['loss'], axis=1) # Features
    y1 = (df.loc[:,'loss'] > 0) # Labels
    y2 = df.loc[:,'loss']
    if describe:
        print(X.shape, y1.shape, y2.shape)
    
    return df, X, y1, y2

# %%
# Load the training data (imputed and normalized) from the CSV file
df, X, y1, y2 = load_csv('train_v2_preprocessed_normalized.csv')

# Separate training and validation sets
from sklearn.model_selection import KFold
kf = KFold(n_splits=5)
X_train, y1_train, X_valid, y1_valid = utils.split_data(kf, X, y1)
X_train, y2_train, X_valid, y2_valid = utils.split_data(kf, X, y2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105471 entries, 0 to 105470
# Columns: 1789 entries, f3 to loss
# dtypes: float64(1789)
# memory usage: 1.4 GB

# %% [markdown]
# ## Adding More Hidden Layers
#
# I will base my implementation on the last part, but add some more hidden layers.

# %%
import tensorflow as tf
import keras
from keras.models import Model, Sequential
from keras.layers import Input, Dense, Activation, Dropout

# %%
# Define parameters

n_features = X.shape[1]
n_epochs = 30
batch_size = 256
class_weight = {0: 1., 1: 10.}

# %% [markdown]
# I will make an arbitrary two-output neural network with some of the layers being shared.

# %%
# Build Keras model

inputs = Input(shape=(n_features,), name='input')
x = Dense(36, activation='relu')(inputs)
x = Dropout(0.5)(x)
x = Dense(18, activation='relu')(x)
x = Dropout(0.5)(x)
x1 = Dense(6, activation='relu')(x)
x1 = Dropout(0.5)(x1)
class_output = Dense(1, activation='sigmoid', name='class_output')(x1)
x2 = keras.layers.concatenate([x, class_output])
x2 = Dense(6, activation='relu')(x2)
x2 = Dropout(0.5)(x2)
regress_output = Dense(1, activation='relu', name='regress_output')(x2)
clf = Model(inputs=inputs, outputs=[class_output, regress_output])

clf.compile(loss={'class_output': 'binary_crossentropy', 'regress_output': 'mean_squared_error'},
            loss_weights={'class_output': 1., 'regress_output': 0.1},
            optimizer=keras.optimizers.Adamax(lr=0.001),
            metrics=['binary_accuracy', 'mse'])

# %%
# Plot the model

from keras.utils import plot_model
plot_model(clf, to_file='model.png')

from IPython.display import Image
Image("model.png")

# %%
import time
import matplotlib.pyplot as plt
from sklearn import metrics

def evaluate (clf, X_train, y1_train, y2_train, X_valid, y1_valid, y2_valid, plot=True):
    # Plotting ROCAUC and PRAUC
    f, (plt1, plt2) = plt.subplots(1, 2, sharey=True, figsize=(12, 4))        
    plt1.set_title('ROC Curve')
    plt1.set_xlabel('FPR')
    plt1.set_ylabel('TPR')
    plt2.set_title('PR Curve')
    plt2.set_xlabel('Precision')
    plt2.set_ylabel('Recall')

    start = time.time()

    # Training set    
    y_train_predicted = clf.predict(X_train)
    fpr, tpr, thresholds = metrics.roc_curve(y1_train.values, y_train_predicted[0])
    precision, recall, thresholds = metrics.precision_recall_curve(y1_train.values, y_train_predicted[0])
    plt1.scatter(fpr, tpr, color='b')    
    plt2.scatter(precision, recall,color='b')
    print('Classification Accuracy (Training): %f' % metrics.accuracy_score(y1_train.values, np.ndarray.round(y_train_predicted[0])))
    print('Regression MSE (Training): %f' % metrics.mean_squared_error(y2_train.values, y_train_predicted[1]))
    print('ROCAUC Score (Training): %f' % metrics.roc_auc_score(y1_train.values, y_train_predicted[0]))
    print('PRAUC Score (Training): %f' % metrics.auc(precision, recall, reorder=True))

    # Validation set
    y_valid_predicted = clf.predict(X_valid)    
    fpr, tpr, thresholds = metrics.roc_curve(y1_valid, y_valid_predicted[0])
    precision, recall, thresholds = metrics.precision_recall_curve(y1_valid.values, y_valid_predicted[0])
    plt1.scatter(fpr, tpr, color='r')
    plt2.scatter(precision, recall,color='r')
    acc_score = metrics.accuracy_score(y1_valid.values, np.ndarray.round(y_valid_predicted[0]))
    print('Classification Accuracy (Validation): %f' % acc_score)
    mse_score = metrics.mean_squared_error(y2_valid.values, y_valid_predicted[1])
    print('Regression MSE (Validation): %f' % mse_score)
    rocauc_score = metrics.roc_auc_score(y1_valid.values, y_valid_predicted[0])
    print('ROCAUC Score (Validation): %f' % rocauc_score)
    prauc_score = metrics.auc(precision, recall, reorder=True)
    print('PRAUC Score (Validation): %f' % prauc_score)

    end = time.time()
    eval_time = end - start
    print('Time elapsed (Evaluation): %.4f s' % eval_time)

    if plot:
        plt.show()
    plt.close()
    
    return acc_score, rocauc_score, prauc_score, eval_time

# %%
# Train and evaluate the model with class weights

fit_time = keras_utils.train_model(clf, X_train, [y1_train, y2_train], n_epochs, batch_size, class_weight)
# Out:
# Epoch 1/30
# 84376/84376 [==============================] - 11s 126us/step - loss: 2.3349 - class_output_loss: 0.4436 - regress_output_loss: 18.9123 - class_output_binary_accuracy: 0.8891 - class_output_mean_squared_error: 0.1315 - regress_output_binary_accuracy: 0.7774 - regress_output_mean_squared_error: 18.9123
# Epoch 2/30
# 84376/84376 [==============================] - 9s 106us/step - loss: 2.2621 - class_output_loss: 0.3839 - regress_output_loss: 18.7816 - class_output_binary_accuracy: 0.9047 - class_output_mean_squared_error: 0.1080 - regress_output_binary_accuracy: 0.7633 - regress_output_mean_squared_error: 18.7816
# Epoch 3/30
# 84376/84376 [==============================] - 9s 107us/step - loss: 2.2215 - class_output_loss: 0.3569 - regress_output_loss: 18.6458 - class_output_binary_accuracy: 0.9059 - class_output_mean_squared_error: 0.0984 - regress_output_binary_accuracy: 0.6967 - regress_output_mean_squared_error: 18.6458
# Epoch 4/30
# 84376/84376 [==============================] - 9s 106us/step - loss: 2.1955 - class_output_loss: 0.3401 - regress_output_loss: 18.5538 - class_output_binary_accuracy: 0.9060 - class_output_mean_squared_error: 0.0933 - regress_output_binary_accuracy: 0.5871 - regress_output_mean_squared_error: 18.5538
# Epoch 5/30
# 84376/84376 [==============================] - 9s 106us/step - loss: 2.1798 - class_output_loss: 0.3304 - regress_output_loss: 18.4940 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0905 - regress_output_binary_accuracy: 0.4429 - regress_output_mean_squared_error: 18.4940
# Epoch 6/30
# 84376/84376 [==============================] - 9s 110us/step - loss: 2.1689 - class_output_loss: 0.3236 - regress_output_loss: 18.4533 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0885 - regress_output_binary_accuracy: 0.3094 - regress_output_mean_squared_error: 18.4533
# Epoch 7/30
# 84376/84376 [==============================] - 9s 109us/step - loss: 2.1606 - class_output_loss: 0.3183 - regress_output_loss: 18.4228 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0872 - regress_output_binary_accuracy: 0.1144 - regress_output_mean_squared_error: 18.4228
# Epoch 8/30
# 84376/84376 [==============================] - 9s 105us/step - loss: 2.1567 - class_output_loss: 0.3152 - regress_output_loss: 18.4154 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0863 - regress_output_binary_accuracy: 0.0388 - regress_output_mean_squared_error: 18.4154 5s - loss: 1.9942 - class_output_loss: 0.3158 - regress_output_loss: 16.7845 - class_output_binary_accuracy: 0.9051 - class_output_mean_squared_error: 0.
# Epoch 9/30
# 84376/84376 [==============================] - 9s 105us/step - loss: 2.1535 - class_output_loss: 0.3130 - regress_output_loss: 18.4049 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0859 - regress_output_binary_accuracy: 0.0321 - regress_output_mean_squared_error: 18.4049
# Epoch 10/30
# 84376/84376 [==============================] - 9s 109us/step - loss: 2.1495 - class_output_loss: 0.3108 - regress_output_loss: 18.3878 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0854 - regress_output_binary_accuracy: 0.0273 - regress_output_mean_squared_error: 18.3878
# Epoch 11/30
# 84376/84376 [==============================] - 8s 101us/step - loss: 2.1490 - class_output_loss: 0.3091 - regress_output_loss: 18.3992 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0851 - regress_output_binary_accuracy: 0.0283 - regress_output_mean_squared_error: 18.3992
# Epoch 12/30
# 84376/84376 [==============================] - 9s 107us/step - loss: 2.1462 - class_output_loss: 0.3079 - regress_output_loss: 18.3824 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0847 - regress_output_binary_accuracy: 0.0291 - regress_output_mean_squared_error: 18.3824
# Epoch 13/30
# 84376/84376 [==============================] - 9s 106us/step - loss: 2.1436 - class_output_loss: 0.3058 - regress_output_loss: 18.3779 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0844 - regress_output_binary_accuracy: 0.0298 - regress_output_mean_squared_error: 18.3779
# Epoch 14/30
# 84376/84376 [==============================] - 9s 102us/step - loss: 2.1439 - class_output_loss: 0.3049 - regress_output_loss: 18.3902 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0841 - regress_output_binary_accuracy: 0.0308 - regress_output_mean_squared_error: 18.3902
# Epoch 15/30
# 84376/84376 [==============================] - 9s 105us/step - loss: 2.1423 - class_output_loss: 0.3047 - regress_output_loss: 18.3758 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0841 - regress_output_binary_accuracy: 0.0302 - regress_output_mean_squared_error: 18.3758
# Epoch 16/30
# 84376/84376 [==============================] - 9s 107us/step - loss: 2.1410 - class_output_loss: 0.3035 - regress_output_loss: 18.3750 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0838 - regress_output_binary_accuracy: 0.0254 - regress_output_mean_squared_error: 18.3750
# Epoch 17/30
# 84376/84376 [==============================] - 9s 107us/step - loss: 2.1411 - class_output_loss: 0.3028 - regress_output_loss: 18.3830 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0837 - regress_output_binary_accuracy: 0.0259 - regress_output_mean_squared_error: 18.3830
# Epoch 18/30
# 84376/84376 [==============================] - 9s 109us/step - loss: 2.1381 - class_output_loss: 0.3018 - regress_output_loss: 18.3631 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0836 - regress_output_binary_accuracy: 0.0336 - regress_output_mean_squared_error: 18.3631
# Epoch 19/30
# 84376/84376 [==============================] - 9s 105us/step - loss: 2.1392 - class_output_loss: 0.3018 - regress_output_loss: 18.3741 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0835 - regress_output_binary_accuracy: 0.0300 - regress_output_mean_squared_error: 18.3741
# Epoch 20/30
# 84376/84376 [==============================] - 9s 106us/step - loss: 2.1374 - class_output_loss: 0.3005 - regress_output_loss: 18.3684 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0834 - regress_output_binary_accuracy: 0.0325 - regress_output_mean_squared_error: 18.3684
# Epoch 21/30
# 84376/84376 [==============================] - 9s 107us/step - loss: 2.1379 - class_output_loss: 0.3004 - regress_output_loss: 18.3749 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0833 - regress_output_binary_accuracy: 0.0308 - regress_output_mean_squared_error: 18.3749
# Epoch 22/30
# 84376/84376 [==============================] - 9s 104us/step - loss: 2.1350 - class_output_loss: 0.2997 - regress_output_loss: 18.3525 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0832 - regress_output_binary_accuracy: 0.0306 - regress_output_mean_squared_error: 18.3525
# Epoch 23/30
# 84376/84376 [==============================] - 9s 107us/step - loss: 2.1360 - class_output_loss: 0.2992 - regress_output_loss: 18.3678 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0831 - regress_output_binary_accuracy: 0.0369 - regress_output_mean_squared_error: 18.3678
# Epoch 24/30
# 84376/84376 [==============================] - 9s 103us/step - loss: 2.1349 - class_output_loss: 0.2987 - regress_output_loss: 18.3624 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0830 - regress_output_binary_accuracy: 0.0326 - regress_output_mean_squared_error: 18.3624
# Epoch 25/30
# 84376/84376 [==============================] - 9s 103us/step - loss: 2.1335 - class_output_loss: 0.2981 - regress_output_loss: 18.3547 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0830 - regress_output_binary_accuracy: 0.0346 - regress_output_mean_squared_error: 18.3547
# Epoch 26/30
# 84376/84376 [==============================] - 9s 106us/step - loss: 2.1343 - class_output_loss: 0.2986 - regress_output_loss: 18.3562 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0830 - regress_output_binary_accuracy: 0.0382 - regress_output_mean_squared_error: 18.3562
# Epoch 27/30
# 84376/84376 [==============================] - 9s 108us/step - loss: 2.1345 - class_output_loss: 0.2983 - regress_output_loss: 18.3618 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0830 - regress_output_binary_accuracy: 0.0390 - regress_output_mean_squared_error: 18.3618
# Epoch 28/30
# 84376/84376 [==============================] - 9s 111us/step - loss: 2.1335 - class_output_loss: 0.2973 - regress_output_loss: 18.3620 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0828 - regress_output_binary_accuracy: 0.0426 - regress_output_mean_squared_error: 18.3620
# Epoch 29/30
# 84376/84376 [==============================] - 9s 108us/step - loss: 2.1333 - class_output_loss: 0.2975 - regress_output_loss: 18.3584 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0829 - regress_output_binary_accuracy: 0.0399 - regress_output_mean_squared_error: 18.3584
# Epoch 30/30
# 84376/84376 [==============================] - 10s 113us/step - loss: 2.1316 - class_output_loss: 0.2968 - regress_output_loss: 18.3482 - class_output_binary_accuracy: 0.9061 - class_output_mean_squared_error: 0.0827 - regress_output_binary_accuracy: 0.0453 - regress_output_mean_squared_error: 18.3482
# Time elapsed (Training): 271.7024 s

# %%
acc_score, rocauc_score, prauc_score, eval_time = evaluate(clf, X_train, y1_train, y2_train, X_valid, y1_valid, y2_valid)
# Out:
# Classification Accuracy (Training): 0.906099
# Regression MSE (Training): 18.333522
# ROCAUC Score (Training): 0.727315
# PRAUC Score (Training): 0.097843
# Classification Accuracy (Validation): 0.911827
# Regression MSE (Validation): 19.841780
# ROCAUC Score (Validation): 0.684865
# PRAUC Score (Validation): 0.133852
# Time elapsed (Evaluation): 10.2817 s

# %% [markdown]
# ## With Discretized Features from Random Forests

# %%
# We need two sets of labels now, one for classification and one for regression

def load_csv(file, describe=False):
    df = pd.read_csv(file, na_values='NA')
    
    # Display basic information
    df.info()
    if describe:
        print(df.describe(include='all'))

    X = df.drop(['loss'], axis=1) # Features
    y1 = (df.loc[:,'loss'] > 0) # Labels
    y2 = df.loc[:,'loss']
    if describe:
        print(X.shape, y1.shape, y2.shape)
    
    return df, X, y1, y2

# %%
# Load the training data (normalized) with random forest paths as features from the CSV file
df, X, y1, y2 = load_csv('train_v2_normalized_with_rf_path.csv')

X_train, y1_train, X_valid, y1_valid = utils.split_data(kf, X, y1)
X_train, y2_train, X_valid, y2_valid = utils.split_data(kf, X, y2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105471 entries, 0 to 105470
# Columns: 3032 entries, Unnamed: 0 to loss
# dtypes: float64(1789), int64(1243)
# memory usage: 2.4 GB

# %%
# Redefine input size

n_features = X.shape[1]

# %%
# Build Keras model

inputs = Input(shape=(n_features,), name='input')
x = Dense(36, activation='relu')(inputs)
x = Dropout(0.2)(x)
x = Dense(18, activation='relu')(x)
x = Dropout(0.2)(x)
x1 = Dense(6, activation='relu')(x)
x1 = Dropout(0.2)(x1)
class_output = Dense(1, activation='sigmoid', name='class_output')(x1)
x2 = keras.layers.concatenate([x, class_output])
x2 = Dense(6, activation='relu')(x2)
x2 = Dropout(0.2)(x2)
regress_output = Dense(1, activation='relu', name='regress_output')(x2)
clf = Model(inputs=inputs, outputs=[class_output, regress_output])

clf.compile(loss={'class_output': 'binary_crossentropy', 'regress_output': 'mean_squared_error'},
            loss_weights={'class_output': 1., 'regress_output': 0.1},
            optimizer=keras.optimizers.Adamax(lr=0.001),
            metrics=['binary_accuracy', 'mse'])

# %%
fit_time = keras_utils.train_model(clf, X_train, [y1_train, y2_train], n_epochs, batch_size, class_weight)
# Out:
# Epoch 1/30
# 84376/84376 [==============================] - 16s 184us/step - loss: 7.0623 - class_output_loss: 2.8216 - regress_output_loss: 42.4071 - class_output_binary_accuracy: 0.8119 - class_output_mean_squared_error: 0.2025 - regress_output_binary_accuracy: 0.9053 - regress_output_mean_squared_error: 42.4071
# Epoch 2/30
# 84376/84376 [==============================] - 15s 176us/step - loss: 4.1825 - class_output_loss: 2.0011 - regress_output_loss: 21.8139 - class_output_binary_accuracy: 0.8637 - class_output_mean_squared_error: 0.1506 - regress_output_binary_accuracy: 0.9059 - regress_output_mean_squared_error: 21.8139
# Epoch 3/30
# 84376/84376 [==============================] - 15s 175us/step - loss: 3.9189 - class_output_loss: 1.7707 - regress_output_loss: 21.4819 - class_output_binary_accuracy: 0.8772 - class_output_mean_squared_error: 0.1332 - regress_output_binary_accuracy: 0.9059 - regress_output_mean_squared_error: 21.4819
# Epoch 4/30
# 84376/84376 [==============================] - 15s 173us/step - loss: 4.1812 - class_output_loss: 1.5222 - regress_output_loss: 26.5898 - class_output_binary_accuracy: 0.8911 - class_output_mean_squared_error: 0.1158 - regress_output_binary_accuracy: 0.9060 - regress_output_mean_squared_error: 26.5898
# Epoch 5/30
# 84376/84376 [==============================] - 15s 175us/step - loss: 3.3989 - class_output_loss: 1.4216 - regress_output_loss: 19.7734 - class_output_binary_accuracy: 0.8973 - class_output_mean_squared_error: 0.1067 - regress_output_binary_accuracy: 0.9060 - regress_output_mean_squared_error: 19.7734
# Epoch 6/30
# 84376/84376 [==============================] - 15s 176us/step - loss: 3.3632 - class_output_loss: 1.3717 - regress_output_loss: 19.9145 - class_output_binary_accuracy: 0.8995 - class_output_mean_squared_error: 0.1020 - regress_output_binary_accuracy: 0.9060 - regress_output_mean_squared_error: 19.9145
# Epoch 7/30
# 84376/84376 [==============================] - 15s 174us/step - loss: 3.2710 - class_output_loss: 1.3373 - regress_output_loss: 19.3366 - class_output_binary_accuracy: 0.9017 - class_output_mean_squared_error: 0.0985 - regress_output_binary_accuracy: 0.9060 - regress_output_mean_squared_error: 19.3366
# Epoch 8/30
# 84376/84376 [==============================] - 15s 172us/step - loss: 3.2399 - class_output_loss: 1.3154 - regress_output_loss: 19.2454 - class_output_binary_accuracy: 0.9034 - class_output_mean_squared_error: 0.0960 - regress_output_binary_accuracy: 0.9060 - regress_output_mean_squared_error: 19.2454
# Epoch 9/30
# 84376/84376 [==============================] - 15s 175us/step - loss: 3.2264 - class_output_loss: 1.3124 - regress_output_loss: 19.1403 - class_output_binary_accuracy: 0.9040 - class_output_mean_squared_error: 0.0951 - regress_output_binary_accuracy: 0.9060 - regress_output_mean_squared_error: 19.1403
# Epoch 10/30
# 84376/84376 [==============================] - 14s 167us/step - loss: 3.3570 - class_output_loss: 1.3120 - regress_output_loss: 20.4508 - class_output_binary_accuracy: 0.9043 - class_output_mean_squared_error: 0.0946 - regress_output_binary_accuracy: 0.9060 - regress_output_mean_squared_error: 20.4508
# Epoch 11/30
# 84376/84376 [==============================] - 15s 182us/step - loss: 3.3157 - class_output_loss: 1.3071 - regress_output_loss: 20.0859 - class_output_binary_accuracy: 0.9046 - class_output_mean_squared_error: 0.0941 - regress_output_binary_accuracy: 0.9060 - regress_output_mean_squared_error: 20.0859
# Epoch 12/30
# 84376/84376 [==============================] - 15s 182us/step - loss: 3.2832 - class_output_loss: 1.2832 - regress_output_loss: 20.0002 - class_output_binary_accuracy: 0.9049 - class_output_mean_squared_error: 0.0934 - regress_output_binary_accuracy: 0.9060 - regress_output_mean_squared_error: 20.0002
# Epoch 13/30
# 84376/84376 [==============================] - 15s 183us/step - loss: 3.2208 - class_output_loss: 1.2934 - regress_output_loss: 19.2741 - class_output_binary_accuracy: 0.9049 - class_output_mean_squared_error: 0.0935 - regress_output_binary_accuracy: 0.9060 - regress_output_mean_squared_error: 19.2741
# Epoch 14/30
# 84376/84376 [==============================] - 15s 180us/step - loss: 3.2193 - class_output_loss: 1.2913 - regress_output_loss: 19.2794 - class_output_binary_accuracy: 0.9048 - class_output_mean_squared_error: 0.0935 - regress_output_binary_accuracy: 0.9061 - regress_output_mean_squared_error: 19.2794
# Epoch 15/30
# 84376/84376 [==============================] - 16s 187us/step - loss: 3.1989 - class_output_loss: 1.2945 - regress_output_loss: 19.0439 - class_output_binary_accuracy: 0.9050 - class_output_mean_squared_error: 0.0933 - regress_output_binary_accuracy: 0.9061 - regress_output_mean_squared_error: 19.0439
# Epoch 16/30
# 84376/84376 [==============================] - 16s 186us/step - loss: 3.1950 - class_output_loss: 1.2803 - regress_output_loss: 19.1473 - class_output_binary_accuracy: 0.9053 - class_output_mean_squared_error: 0.0929 - regress_output_binary_accuracy: 0.9061 - regress_output_mean_squared_error: 19.1473
# Epoch 17/30
# 84376/84376 [==============================] - 16s 185us/step - loss: 3.1862 - class_output_loss: 1.2758 - regress_output_loss: 19.1047 - class_output_binary_accuracy: 0.9053 - class_output_mean_squared_error: 0.0928 - regress_output_binary_accuracy: 0.9061 - regress_output_mean_squared_error: 19.1047
# Epoch 18/30
# 84376/84376 [==============================] - 16s 186us/step - loss: 3.2140 - class_output_loss: 1.2709 - regress_output_loss: 19.4315 - class_output_binary_accuracy: 0.9053 - class_output_mean_squared_error: 0.0928 - regress_output_binary_accuracy: 0.9060 - regress_output_mean_squared_error: 19.4315
# Epoch 19/30
# 84376/84376 [==============================] - 16s 186us/step - loss: 3.1995 - class_output_loss: 1.2891 - regress_output_loss: 19.1039 - class_output_binary_accuracy: 0.9054 - class_output_mean_squared_error: 0.0930 - regress_output_binary_accuracy: 0.9061 - regress_output_mean_squared_error: 19.1039
# Epoch 20/30
# 84376/84376 [==============================] - 16s 188us/step - loss: 3.2564 - class_output_loss: 1.2786 - regress_output_loss: 19.7780 - class_output_binary_accuracy: 0.9054 - class_output_mean_squared_error: 0.0928 - regress_output_binary_accuracy: 0.9061 - regress_output_mean_squared_error: 19.7780
# Epoch 21/30
# 84376/84376 [==============================] - 15s 183us/step - loss: 3.2041 - class_output_loss: 1.2685 - regress_output_loss: 19.3564 - class_output_binary_accuracy: 0.9056 - class_output_mean_squared_error: 0.0925 - regress_output_binary_accuracy: 0.9061 - regress_output_mean_squared_error: 19.3564
# Epoch 22/30
# 84376/84376 [==============================] - 16s 185us/step - loss: 3.1920 - class_output_loss: 1.2848 - regress_output_loss: 19.0725 - class_output_binary_accuracy: 0.9056 - class_output_mean_squared_error: 0.0927 - regress_output_binary_accuracy: 0.9061 - regress_output_mean_squared_error: 19.0725
# Epoch 23/30
# 84376/84376 [==============================] - 15s 178us/step - loss: 3.2166 - class_output_loss: 1.2783 - regress_output_loss: 19.3825 - class_output_binary_accuracy: 0.9056 - class_output_mean_squared_error: 0.0927 - regress_output_binary_accuracy: 0.9061 - regress_output_mean_squared_error: 19.3825
# Epoch 24/30
# 84376/84376 [==============================] - 15s 178us/step - loss: 3.1654 - class_output_loss: 1.2624 - regress_output_loss: 19.0297 - class_output_binary_accuracy: 0.9057 - class_output_mean_squared_error: 0.0923 - regress_output_binary_accuracy: 0.9061 - regress_output_mean_squared_error: 19.0297
# Epoch 25/30
# 84376/84376 [==============================] - 15s 179us/step - loss: 3.2070 - class_output_loss: 1.2732 - regress_output_loss: 19.3383 - class_output_binary_accuracy: 0.9056 - class_output_mean_squared_error: 0.0926 - regress_output_binary_accuracy: 0.9061 - regress_output_mean_squared_error: 19.3383
# Epoch 26/30
# 84376/84376 [==============================] - 16s 186us/step - loss: 3.2448 - class_output_loss: 1.2762 - regress_output_loss: 19.6857 - class_output_binary_accuracy: 0.9056 - class_output_mean_squared_error: 0.0926 - regress_output_binary_accuracy: 0.9061 - regress_output_mean_squared_error: 19.6857
# Epoch 27/30
# 84376/84376 [==============================] - 15s 176us/step - loss: 3.1696 - class_output_loss: 1.2677 - regress_output_loss: 19.0197 - class_output_binary_accuracy: 0.9055 - class_output_mean_squared_error: 0.0926 - regress_output_binary_accuracy: 0.9061 - regress_output_mean_squared_error: 19.0197
# Epoch 28/30
# 84376/84376 [==============================] - 14s 171us/step - loss: 3.1701 - class_output_loss: 1.2671 - regress_output_loss: 19.0303 - class_output_binary_accuracy: 0.9056 - class_output_mean_squared_error: 0.0926 - regress_output_binary_accuracy: 0.9061 - regress_output_mean_squared_error: 19.0303
# Epoch 29/30
# 84376/84376 [==============================] - 15s 175us/step - loss: 3.1852 - class_output_loss: 1.2678 - regress_output_loss: 19.1738 - class_output_binary_accuracy: 0.9058 - class_output_mean_squared_error: 0.0924 - regress_output_binary_accuracy: 0.9061 - regress_output_mean_squared_error: 19.1738
# Epoch 30/30
# 84376/84376 [==============================] - 15s 174us/step - loss: 3.2151 - class_output_loss: 1.2620 - regress_output_loss: 19.5319 - class_output_binary_accuracy: 0.9056 - class_output_mean_squared_error: 0.0925 - regress_output_binary_accuracy: 0.9061 - regress_output_mean_squared_error: 19.5319
# Time elapsed (Training): 455.3696 s

# %%
acc_score, rocauc_score, prauc_score, eval_time = evaluate(clf, X_train, y1_train, y2_train, X_valid, y1_valid, y2_valid)
# Out:
# Classification Accuracy (Training): 0.906099
# Regression MSE (Training): 19.019401
# ROCAUC Score (Training): 0.500000
# PRAUC Score (Training): 0.453049
# Classification Accuracy (Validation): 0.911827
# Regression MSE (Validation): 20.478502
# ROCAUC Score (Validation): 0.495123
# PRAUC Score (Validation): 0.002449
# Time elapsed (Evaluation): 16.9166 s

# %% [markdown]
# ## With Discretized Features from Gradient-Boosted Decision Trees

# %%
# Load the training data (normalized) with gradient-boosted tree leaves as features from the CSV file
df, X, y1, y2 = load_csv('train_v2_normalized_with_gb_leaf.csv')

X_train, y1_train, X_valid, y1_valid = utils.split_data(kf, X, y1)
X_train, y2_train, X_valid, y2_valid = utils.split_data(kf, X, y2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105471 entries, 0 to 105470
# Columns: 1010 entries, Unnamed: 0 to loss
# dtypes: float64(1009), int64(1)
# memory usage: 812.7 MB

# %%
# Redefine input size

n_features = X.shape[1]

# %%
# Build Keras model

inputs = Input(shape=(n_features,), name='input')
x = Dense(36, activation='relu')(inputs)
x = Dropout(0.2)(x)
x = Dense(18, activation='relu')(x)
x = Dropout(0.2)(x)
x1 = Dense(6, activation='relu')(x)
x1 = Dropout(0.2)(x1)
class_output = Dense(1, activation='sigmoid', name='class_output')(x1)
x2 = keras.layers.concatenate([x, class_output])
x2 = Dense(6, activation='relu')(x2)
x2 = Dropout(0.2)(x2)
regress_output = Dense(1, activation='relu', name='regress_output')(x2)
clf = Model(inputs=inputs, outputs=[class_output, regress_output])

clf.compile(loss={'class_output': 'binary_crossentropy', 'regress_output': 'mean_squared_error'},
            loss_weights={'class_output': 1., 'regress_output': 0.1},
            optimizer=keras.optimizers.Adamax(lr=0.001),
            metrics=['binary_accuracy', 'mse'])

# %%
acc_score, rocauc_score, prauc_score, eval_time = evaluate(clf, X_train, y1_train, y2_train, X_valid, y1_valid, y2_valid)
# Out:
# Classification Accuracy (Training): 0.906099
# Regression MSE (Training): 976876.772772
# ROCAUC Score (Training): 0.491423
# PRAUC Score (Training): 0.002114
# Classification Accuracy (Validation): 0.911496
# Regression MSE (Validation): 31336.288719
# ROCAUC Score (Validation): 0.498325
# PRAUC Score (Validation): 0.010309
# Time elapsed (Evaluation): 5.3396 s
